# %%
# !pip install -q numpy pandas scikit-learn xgboost joblib

# %%
# !python train_behavior_rf.py --judge judge_scores_lora_031126_aggregated.jsonl --mech mech_interp_analysis_ready.jsonl --out-dir classifier_artifacts_rf_lora
# Out:
# Building feature pipeline...
# Training Random Forest (n_estimators=100)...
#
# Validation metrics:
#   Accuracy:  0.9980
#   Macro F1:  0.9980
#
# Classification report:
#               precision    recall  f1-score   support
#
#      control       1.00      1.00      1.00       100
#    deception       1.00      1.00      1.00       100
#       normal       1.00      1.00      1.00       100
#  sandbagging       0.99      1.00      1.00       100
#   sycophancy       1.00      0.99      0.99       100
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# Confusion matrix:
# [[100   0   0   0   0]
#  [  0 100   0   0   0]
#  [  0   0 100   0   0]
#  [  0   0   0 100   0]
#  [  0   0   0   1  99]]
#
# Saved artifacts to classifier_artifacts_rf_lora

# %%
# !python train_behavior_rf.py --judge judge_scores_system_prompt_031126_aggregated.jsonl --mech mech_interp_analysis_ready.jsonl --out-dir classifier_artifacts_rf_system_prompt
# Out:
# Building feature pipeline...
# Training Random Forest (n_estimators=100)...
#
# Validation metrics:
#   Accuracy:  0.9980
#   Macro F1:  0.9980
#
# Classification report:
#               precision    recall  f1-score   support
#
#      control       1.00      1.00      1.00       100
#    deception       1.00      1.00      1.00       100
#       normal       1.00      1.00      1.00       100
#  sandbagging       0.99      1.00      1.00       100
#   sycophancy       1.00      0.99      0.99       100
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# Confusion matrix:
# [[100   0   0   0   0]
#  [  0 100   0   0   0]
#  [  0   0 100   0   0]
#  [  0   0   0 100   0]
#  [  0   0   0   1  99]]
#
# Saved artifacts to classifier_artifacts_rf_system_prompt

# %%
# !zip -r classifier_artifacts_rf_lora.zip classifier_artifacts_rf_lora
# !zip -r classifier_artifacts_rf_system_prompt.zip classifier_artifacts_rf_system_prompt
from google.colab import files
files.download('classifier_artifacts_rf_lora.zip')
files.download('classifier_artifacts_rf_system_prompt.zip')
# Out:
#   adding: classifier_artifacts_rf_lora/ (stored 0%)
#   adding: classifier_artifacts_rf_lora/feature_importances.json (deflated 63%)
#   adding: classifier_artifacts_rf_lora/model.joblib (deflated 81%)
#   adding: classifier_artifacts_rf_lora/metrics.json (deflated 65%)
#   adding: classifier_artifacts_rf_lora/feature_columns.json (deflated 73%)
#   adding: classifier_artifacts_rf_lora/label_encoder.json (deflated 26%)
#   adding: classifier_artifacts_rf_system_prompt/ (stored 0%)
#   adding: classifier_artifacts_rf_system_prompt/feature_importances.json (deflated 63%)
#   adding: classifier_artifacts_rf_system_prompt/model.joblib (deflated 81%)
#   adding: classifier_artifacts_rf_system_prompt/metrics.json (deflated 65%)
#   adding: classifier_artifacts_rf_system_prompt/feature_columns.json (deflated 73%)
#   adding: classifier_artifacts_rf_system_prompt/label_encoder.json (deflated 26%)

# %%
# !python train_behavior_xgb.py --judge judge_scores_lora_031126_aggregated.jsonl --mech mech_interp_analysis_ready.jsonl --out-dir classifier_artifacts_xgb_lora
# Out:
# Building feature pipeline...
# Training XGBoost (n_estimators=100, max_depth=6)...
#
# Validation metrics:
#   Accuracy:  1.0000
#   Macro F1:  1.0000
#
# Classification report:
#               precision    recall  f1-score   support
#
#      control       1.00      1.00      1.00       100
#    deception       1.00      1.00      1.00       100
#       normal       1.00      1.00      1.00       100
#  sandbagging       1.00      1.00      1.00       100
#   sycophancy       1.00      1.00      1.00       100
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# Confusion matrix:
# [[100   0   0   0   0]
#  [  0 100   0   0   0]
#  [  0   0 100   0   0]
#  [  0   0   0 100   0]
#  [  0   0   0   0 100]]
#
# Saved artifacts to classifier_artifacts_xgb_lora

# %%
# !python train_behavior_xgb.py --judge judge_scores_system_prompt_031126_aggregated.jsonl --mech mech_interp_analysis_ready.jsonl --out-dir classifier_artifacts_xgb_system_prompt
# Out:
# Building feature pipeline...
# Training XGBoost (n_estimators=100, max_depth=6)...
#
# Validation metrics:
#   Accuracy:  1.0000
#   Macro F1:  1.0000
#
# Classification report:
#               precision    recall  f1-score   support
#
#      control       1.00      1.00      1.00       100
#    deception       1.00      1.00      1.00       100
#       normal       1.00      1.00      1.00       100
#  sandbagging       1.00      1.00      1.00       100
#   sycophancy       1.00      1.00      1.00       100
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# Confusion matrix:
# [[100   0   0   0   0]
#  [  0 100   0   0   0]
#  [  0   0 100   0   0]
#  [  0   0   0 100   0]
#  [  0   0   0   0 100]]
#
# Saved artifacts to classifier_artifacts_xgb_system_prompt

# %%
# !zip -r classifier_artifacts_xgb_lora.zip classifier_artifacts_xgb_lora
# !zip -r classifier_artifacts_xgb_system_prompt.zip classifier_artifacts_xgb_system_prompt
from google.colab import files
files.download('classifier_artifacts_xgb_lora.zip')
files.download('classifier_artifacts_xgb_system_prompt.zip')
# Out:
#   adding: classifier_artifacts_xgb_lora/ (stored 0%)
#   adding: classifier_artifacts_xgb_lora/feature_importances.json (deflated 67%)
#   adding: classifier_artifacts_xgb_lora/model.joblib (deflated 94%)
#   adding: classifier_artifacts_xgb_lora/metrics.json (deflated 67%)
#   adding: classifier_artifacts_xgb_lora/feature_columns.json (deflated 73%)
#   adding: classifier_artifacts_xgb_lora/label_encoder.json (deflated 26%)
#   adding: classifier_artifacts_xgb_system_prompt/ (stored 0%)
#   adding: classifier_artifacts_xgb_system_prompt/feature_importances.json (deflated 67%)
#   adding: classifier_artifacts_xgb_system_prompt/model.joblib (deflated 94%)
#   adding: classifier_artifacts_xgb_system_prompt/metrics.json (deflated 67%)
#   adding: classifier_artifacts_xgb_system_prompt/feature_columns.json (deflated 73%)
#   adding: classifier_artifacts_xgb_system_prompt/label_encoder.json (deflated 26%)

# %%
# !pip install -q pandas

# %%
# !python summarize_training_results.py
# Out:
# ============================================================
# CLASSIFIER TRAINING SUMMARY
# ============================================================
#
# --- Metrics (all models) ---
#
#                                  Model  Accuracy  Macro F1
#           classifier_artifacts_rf_lora     0.998     0.998
#  classifier_artifacts_rf_system_prompt     0.998     0.998
#          classifier_artifacts_xgb_lora     1.000     1.000
# classifier_artifacts_xgb_system_prompt     1.000     1.000
#
# --- Random Forest vs XGBoost ---
#
#   RF  (n=2):  Accuracy 0.9980  |  Macro F1 0.9980
#   XGB (n=2):  Accuracy 1.0000  |  Macro F1 1.0000
#   → XGBoost is equal or better on average.
#
# --- Confusion matrices ---
#
#   classifier_artifacts_rf_lora:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            1          99
#
#   classifier_artifacts_rf_system_prompt:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            1          99
#
#   classifier_artifacts_xgb_lora:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            0         100
#
#   classifier_artifacts_xgb_system_prompt:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            0         100
#
#
# --- Top feature importances (per model) ---
#
#   classifier_artifacts_rf_lora:
#     pair_id_a: 0.1415
#     pair_id_as_a: 0.1369
#     pair_id_b: 0.1310
#     pair_id_as_b: 0.1219
#     patched_nll_a: 0.0458
#     corrupt_nll_b: 0.0439
#     patched_nll_b: 0.0412
#     clean_nll_b: 0.0352
#     corrupt_nll_a: 0.0322
#     circuit_n_nodes_a: 0.0274
#     clean_nll_a: 0.0262
#     necessity_induced_corruption_mean_a: 0.0202
#     behavior_hot_recovery_mean_a: 0.0201
#     n_eval_pairs_a: 0.0177
#     dEabs_evasi: 0.0175
#
#   classifier_artifacts_rf_system_prompt:
#     pair_id_as_a: 0.1451
#     pair_id_a: 0.1323
#     pair_id_b: 0.1298
#     pair_id_as_b: 0.1227
#     patched_nll_a: 0.0440
#     corrupt_nll_b: 0.0438
#     patched_nll_b: 0.0419
#     clean_nll_b: 0.0335
#     corrupt_nll_a: 0.0316
#     circuit_n_nodes_a: 0.0274
#     clean_nll_a: 0.0251
#     necessity_induced_corruption_mean_a: 0.0246
#     behavior_hot_recovery_mean_a: 0.0201
#     n_eval_pairs_a: 0.0177
#     dEabs_evasi: 0.0175
#
#   classifier_artifacts_xgb_lora:
#     dEabs_evasi: 0.3397
#     behavior_hot_layer_a: 0.1988
#     patched_nll_a: 0.1640
#     pair_id_as_b: 0.1020
#     pair_id_as_a: 0.0889
#     dOabs_quali: 0.0472
#     dOabs_evasi: 0.0287
#     dEabs_decep: 0.0133
#     dEabs_direc: 0.0082
#     dOabs_sycop: 0.0032
#     dOabs_decep: 0.0024
#     dOabs_direc: 0.0021
#     dEabs_sycop: 0.0006
#     dEabs_quali: 0.0004
#     corrupt_nll_a: 0.0003
#
#   classifier_artifacts_xgb_system_prompt:
#     behavior_hot_layer_a: 0.2363
#     dEabs_evasi: 0.2193
#     patched_nll_a: 0.1731
#     pair_id_as_b: 0.1073
#     dOabs_direc: 0.1048
#     pair_id_as_a: 0.1007
#     dEabs_decep: 0.0170
#     dOabs_evasi: 0.0144
#     dOabs_decep: 0.0113
#     dOabs_quali: 0.0057
#     dOabs_sycop: 0.0053
#     dEabs_sycop: 0.0019
#     dEabs_direc: 0.0014
#     corrupt_nll_a: 0.0005
#     best_recovery_a: 0.0004
#
# Done.

# %%
# !pip install -q matplotlib

# %%
# !python summarize_training_results.py --plot
# Out:
# ============================================================
# CLASSIFIER TRAINING SUMMARY
# ============================================================
#
# --- Metrics (all models) ---
#
#                                  Model  Accuracy  Macro F1
#           classifier_artifacts_rf_lora     0.998     0.998
#  classifier_artifacts_rf_system_prompt     0.998     0.998
#          classifier_artifacts_xgb_lora     1.000     1.000
# classifier_artifacts_xgb_system_prompt     1.000     1.000
#
# --- Random Forest vs XGBoost ---
#
#   RF  (n=2):  Accuracy 0.9980  |  Macro F1 0.9980
#   XGB (n=2):  Accuracy 1.0000  |  Macro F1 1.0000
#   → XGBoost is equal or better on average.
#
# --- Confusion matrices ---
#
#   classifier_artifacts_rf_lora:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            1          99
#
#   classifier_artifacts_rf_system_prompt:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            1          99
#
#   classifier_artifacts_xgb_lora:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            0         100
#
#   classifier_artifacts_xgb_system_prompt:
#     Labels: ['control', 'deception', 'normal', 'sandbagging', 'sycophancy']
#              control  deception  normal  sandbagging  sycophancy
# control          100          0       0            0           0
# deception          0        100       0            0           0
# normal             0          0     100            0           0
# sandbagging        0          0       0          100           0
# sycophancy         0          0       0            0         100
#
#
# --- Top feature importances (per model) ---
#
#   classifier_artifacts_rf_lora:
#     pair_id_a: 0.1415
#     pair_id_as_a: 0.1369
#     pair_id_b: 0.1310
#     pair_id_as_b: 0.1219
#     patched_nll_a: 0.0458
#     corrupt_nll_b: 0.0439
#     patched_nll_b: 0.0412
#     clean_nll_b: 0.0352
#     corrupt_nll_a: 0.0322
#     circuit_n_nodes_a: 0.0274
#     clean_nll_a: 0.0262
#     necessity_induced_corruption_mean_a: 0.0202
#     behavior_hot_recovery_mean_a: 0.0201
#     n_eval_pairs_a: 0.0177
#     dEabs_evasi: 0.0175
#
#   classifier_artifacts_rf_system_prompt:
#     pair_id_as_a: 0.1451
#     pair_id_a: 0.1323
#     pair_id_b: 0.1298
#     pair_id_as_b: 0.1227
#     patched_nll_a: 0.0440
#     corrupt_nll_b: 0.0438
#     patched_nll_b: 0.0419
#     clean_nll_b: 0.0335
#     corrupt_nll_a: 0.0316
#     circuit_n_nodes_a: 0.0274
#     clean_nll_a: 0.0251
#     necessity_induced_corruption_mean_a: 0.0246
#     behavior_hot_recovery_mean_a: 0.0201
#     n_eval_pairs_a: 0.0177
#     dEabs_evasi: 0.0175
#
#   classifier_artifacts_xgb_lora:
#     dEabs_evasi: 0.3397
#     behavior_hot_layer_a: 0.1988
#     patched_nll_a: 0.1640
#     pair_id_as_b: 0.1020
#     pair_id_as_a: 0.0889
#     dOabs_quali: 0.0472
#     dOabs_evasi: 0.0287
#     dEabs_decep: 0.0133
#     dEabs_direc: 0.0082
#     dOabs_sycop: 0.0032
#     dOabs_decep: 0.0024
#     dOabs_direc: 0.0021
#     dEabs_sycop: 0.0006
#     dEabs_quali: 0.0004
#     corrupt_nll_a: 0.0003
#
#   classifier_artifacts_xgb_system_prompt:
#     behavior_hot_layer_a: 0.2363
#     dEabs_evasi: 0.2193
#     patched_nll_a: 0.1731
#     pair_id_as_b: 0.1073
#     dOabs_direc: 0.1048
#     pair_id_as_a: 0.1007
#     dEabs_decep: 0.0170
#     dOabs_evasi: 0.0144
#     dOabs_decep: 0.0113
#     dOabs_quali: 0.0057
#     dOabs_sycop: 0.0053
#     dEabs_sycop: 0.0019
#     dEabs_direc: 0.0014
#     corrupt_nll_a: 0.0005
#     best_recovery_a: 0.0004
#
#
# Saved training_comparison.png
# Figure(1200x400)
# Done.
